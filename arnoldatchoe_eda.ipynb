# %% [markdown]
# # EXPLORATORY ANALYSIS OF THE IRIS DATASET
# # AUTHOR: ARNOLD ATCHOE
# # DATE: 09/22/2024
# # PROJECT PURPOSE
# The goal of this project is to investigate the iris dataset. We aim to identify specific features of the dataset, including:
# 1. The dataset's cleanliness.
# 2. The distribution of the data.
# 3. The measures of central tendency in the dataset.
# We will also engage in data transformation and feature engineering as needed. The aim of our exploratory data analysis is to tell a compelling story with our data through the use of appropriate visuals.
#
# The iris dataset measures the petal length, petal width, sepal length and sepal width of various species of iris flowers.

# %% [markdown]
# ## STEP 1: IMPORT LIBRARIES
# This first step in our exploratory analysis is to import the needed dependencies or libraries for our project. In this project, we are using mathplotlib, pandas and seaborn. These libraries have been installed within our project virtual environment.

# %%
# Import needed libraries with aliases

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## STEP 2: DATA ACQUISITION
# The second step is to load our dataset. In many instances, we work with datasets not supplied by Python libraries. When that’s the case, we utilize various reading methods or functions from the pandas library, such as pd.read_csv() and pd.read_excel(), to import datasets into Python. However, for this project, we are using a dataset from the seaborn library, which we load using the command shown in the code window below.

# %%
# Load dataset from seaborn library
df = sns.load_dataset("iris")

# Inspect dataset
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## STEP 3: INITIAL DATA INSPECTION
# We familiarize ourselves with the data using the commands in the code box below. This step helps us understand several characteristics of our dataset, including:
# 1. The number of rows and columns.
# 2. The data types of each column.
# 3. The count of non-null values in each column.
# 4. The memory usage of the dataset.

# %%
# Print first 10 rows 
print(df.head(10))

# Print number of columns and rows
print(df.shape)

# Print data type of each column
print(df.dtypes)

# Print the same information as the immediate two functions above as well as number of non-null values in each column and memory usage of dataset.
print(df.info())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa
# (150, 5)
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# ...

# %% [markdown]
# ## STEP 4: INITIAL DESCRIPTIVE STATISTICS
# The next code box generates summary statistics for the numerical columns in our dataset. This allows us to understand the mean, median, minimum and maximum values, various percentiles, standard deviation, and count for each column.

# %%
# Print summary statistics for numerical columns
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## STEP 5: INITIAL DISTRIBUTION OF NUMERICAL COLUMNS
# We check the distribution of our numerical features or columns over their range. We can use the first line of the code box below to check distribution of specific columns or check distribution for all columns simultaneously using the second line of the code box below.

# %%
# Inspect histogram for specific numerical columns
Columns = ['sepal_length','sepal_width','petal_length']
for column in Columns:
 df[column].hist()

# Inspect histogram for all numerical columns
df.hist()

# Show all plots or histogram
plt.show()

# %% [markdown]
# ## OBSERVATION 1: NUMERICAL COLUMN DISTRIBUTION
# 1. SEPAL LENGTH: The sepal length ranges from 4cm to 8cm. Most of the iris flowers have sepal lenght of less that 7cm.
# 2. SEPAL WIDTH: Most of the iris flowers used in this dataset had a sepal width between 2.5cm and 3.8cm, clustered close to the mean of approximately 3cm.
# 3. PETAL LENGTH: About two-thirds of the iris flowers studied have petal lengths ranging from 3cm to 6.9cm. The other one-third is below 2.5cm.
# 4. PETAL WIDTH: Petal width for the iris flowers in our dataset ranges from 0.1cm to 2.5cm with majority being over approximately 0.8cm.

# %% [markdown]
# ## STEP 6: INITIAL DISTRIBUTION OF CATEGORICAL COLUMNS
# We check the distribution of our categorical features or columns among unique categories. We can use the first line of the code box below to check distribution of specific columns or check distribution for all columns simultaneously using the second line of the code box below.

# %%
# Inspect value counts by categorical column
df['species'].value_counts()

# Inspect value counts for all categorical columns
for col in df.select_dtypes(include=['object', 'category']).columns:
    # Display count plot
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# Show all plots
plt.show()

# %% [markdown]
# ## OBSERVATION 2:CATEGORICAL COLUMN DISTRIBUTION
# From the histogram above, we can observe that the number of iris flowers is equal across the different species.

# %% [markdown]
# ## STEP 7: DATA TRANSFORMATION AND ENGINEERING
# In this sept, we rename the sepal_length column and also created a new column called Sepal_Area, a result of the product of Sepal_Length and sepal_width.

# %%
# Renaming columns to include unit of measurement for width and length
df.rename(columns={'sepal_length': 'sepal_length_cm'}, inplace=True)
df.rename(columns={'sepal_width': 'sepal_width_cm'}, inplace=True)
df.rename(columns={'petal_length': 'petal_length_cm'}, inplace=True)
df.rename(columns={'petal_width': 'petal_width_cm'}, inplace=True)

# Adding a new column
df['sepal_Area'] = df['sepal_length_cm'] * df['sepal_width_cm']
df['petal_Area'] = df['petal_length_cm'] * df['petal_width_cm']

# %%
# Checking the relationship between various numerical variables.

# Create scatter plots to examine the relationship between numerical columns or features of your DataFrame
plt = sns.pairplot(data=df, hue="species")

# Run this cell by clicking the play button (Execute cell and below) in the cell toolbar
# Or by pressing Shift+Enter 
# or by clicking Run All in the Menu above

# %% [markdown]
# ## OBSERVATION 3: RELATIONSHIPS BETWEEN NUMERICAL VARIABLES
# 1. Sepal width and sepal lenght are highly correlated with sepal area for all iris flower species.
# 2. Sepal width and sepal lenght are highly correlated for setosa species and moderately correlated for the virginica and versicolor species.
# 3. Setosa has low petal width and lenght.
# 4. Versicolor has moderate or average width and length.
# 5. Virginica has high petal width and length.
# 6. Sepal width and sepal lenght are highly correlated with sepal area for all iris flower species.
